# %% [markdown]
# # How does the non-football attributes of a footballer affect his wages?

# %% [markdown]
# ### Essential Libraries
#
# Let us begin by importing the essential Python Libraries.
#
# > NumPy : Library for Numeric Computations in Python
# > Pandas : Library for Data Acquisition and Preparation
# > Matplotlib : Low-level library for Data Visualization
# > Seaborn : Higher-level library for Data Visualization

# %%
# Basic Libraries

import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ### Import the Fifa Dataset
#
# The dataset is in CSV format; hence we use the `read_csv` function from Pandas to impart the FIFA 19 Dataset

# %%
fifaData = pd.read_csv('Fifa 19.csv')
fifaData.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %% [markdown]
# ### Dropping the columns of data that cannot be used
#
# Firstly, we decided to drop the columns of data which contains variables that definitely cannot be used in determining wages. This is because it does not give any valuable information whatsoever.
#
# The columns are 'ID', 'Photo', 'Flag', 'Club', 'Club Logo','Value', 'Special', 'Preferred Foot', 'Work Rate',
#                'International Reputation', 'Weak Foot', 'Position', 'Skill Moves', 'Body Type',
#                'Real Face', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until' and
#                'Release Clause'

# %%
fifaData.drop(['ID', 'Photo', 'Flag', 'Club', 'Club Logo', 'Value', 'Special', 'Preferred Foot', 'Work Rate', 
               'International Reputation', 'Weak Foot', 'Position', 'Skill Moves', 'Body Type', 
               'Real Face', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until', 
               'Release Clause'], axis = 1, inplace = True)

# %%
fifaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 69 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       18207 non-null  int64
#  1   Name             18207 non-null  object
#  2   Age              18207 non-null  int64
#  3   Nationality      18207 non-null  object
#  4   Overall          18207 non-null  int64
#  5   Potential        18207 non-null  int64
#  6   Wage             18207 non-null  object
#  7   Height           18159 non-null  object
#  8   Weight           18159 non-null  object
#  9   LS               16122 non-null  object
#  10  ST               16122 non-null  object
#  11  RS               16122 non-null  object
#  12  LW               16122 non-null  object
#  13  LF               16122 non-null  object
#  14  CF               16122 non-null  object
#  15  RF               16122 non-null  object
# ...

# %% [markdown]
# ### Dropping the columns of data that are non-specific
#
# We also decided to drop the columns of data which contains the ratings of players when placed in every position there is. This data is non-specific and cannot be used. (why can't it be used?)
#
# A much better variable to be used is Overall, since it takes into account the average of all of the positions combined.
#
# The columns being dropped are 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#                'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#                'LCB', 'CB', 'RCB', and 'RB'.

# %%
fifaData.drop(fifaData.iloc[:, 9:35], inplace = True, axis = 1)

# %%
fifaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 43 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       18207 non-null  int64
#  1   Name             18207 non-null  object
#  2   Age              18207 non-null  int64
#  3   Nationality      18207 non-null  object
#  4   Overall          18207 non-null  int64
#  5   Potential        18207 non-null  int64
#  6   Wage             18207 non-null  object
#  7   Height           18159 non-null  object
#  8   Weight           18159 non-null  object
#  9   Crossing         18159 non-null  float64
#  10  Finishing        18159 non-null  float64
#  11  HeadingAccuracy  18159 non-null  float64
#  12  ShortPassing     18159 non-null  float64
#  13  Volleys          18159 non-null  float64
#  14  Dribbling        18159 non-null  float64
#  15  Curve            18159 non-null  float64
# ...

# %% [markdown]
# ### Dropping the columns of data that are football-related
#
# Lastly, we decided to drop the specific statistics because the aim of our project is to find out how non-football statistics determine wages.
#
#
# The columns being dropped are 'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning' and 'GKReflexes'.

# %%
fifaData.drop(fifaData.iloc[:, 9:43], inplace = True, axis = 1)

# %%
fifaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   18207 non-null  int64
#  1   Name         18207 non-null  object
#  2   Age          18207 non-null  int64
#  3   Nationality  18207 non-null  object
#  4   Overall      18207 non-null  int64
#  5   Potential    18207 non-null  int64
#  6   Wage         18207 non-null  object
#  7   Height       18159 non-null  object
#  8   Weight       18159 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Data Cleaning
#
# We will now be focussing on the variables that we are most probably going to use in determining wages. But first, we would have to clean the data appropriately so that we are able to utilise them.

# %%
fifaData.head()
# Out:
#    Unnamed: 0               Name  Age Nationality  Overall  Potential   Wage  \
# 0           0           L. Messi   31   Argentina       94         94  €565K
# 1           1  Cristiano Ronaldo   33    Portugal       94         94  €405K
# 2           2          Neymar Jr   26      Brazil       92         93  €290K
# 3           3             De Gea   27       Spain       91         93  €260K
# 4           4       K. De Bruyne   27     Belgium       91         92  €355K
#
#   Height  Weight
# 0    5'7  159lbs
# 1    6'2  183lbs
# 2    5'9  150lbs
# 3    6'4  168lbs
# 4   5'11  154lbs

# %%
#Cleaning the Wage and making it Dtype integer instead of object

fifaData['Wage'] = fifaData['Wage'].str.replace('€', '')
fifaData['Wage'] = fifaData['Wage'].str.replace('K', '').astype(int)

#Removing the rows with Wage 0
fifaData = fifaData.loc[fifaData["Wage"] != 0]

#Renaming the column from Wage to Wage (in Thousands)
fifaData = fifaData.rename(columns={'Wage': 'Wage (Thousands)'})

# %%
fifaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17966 entries, 0 to 18206
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        17966 non-null  int64
#  1   Name              17966 non-null  object
#  2   Age               17966 non-null  int64
#  3   Nationality       17966 non-null  object
#  4   Overall           17966 non-null  int64
#  5   Potential         17966 non-null  int64
#  6   Wage (Thousands)  17966 non-null  int64
#  7   Height            17918 non-null  object
#  8   Weight            17918 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 1.4+ MB

# %%
#Cleaning the Height and making it Dtype integer instead of object

fifaData['Height'] = fifaData['Height'].str.replace("'", ".").astype(float)
fifaData['Height'] = fifaData['Height'].multiply(30.48).round(1)

#Renaming the column from Height to Height (cm)
fifaData = fifaData.rename(columns={'Height': 'Height (cm)'})

# %%
fifaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17966 entries, 0 to 18206
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        17966 non-null  int64
#  1   Name              17966 non-null  object
#  2   Age               17966 non-null  int64
#  3   Nationality       17966 non-null  object
#  4   Overall           17966 non-null  int64
#  5   Potential         17966 non-null  int64
#  6   Wage (Thousands)  17966 non-null  int64
#  7   Height (cm)       17918 non-null  float64
#  8   Weight            17918 non-null  object
# dtypes: float64(1), int64(5), object(3)
# memory usage: 1.4+ MB

# %%
#Cleaning the Weight 
fifaData['Weight'] = fifaData['Weight'].str.replace('lbs', '')

#Removing the rows with NULL Weight
fifaData.dropna(subset=['Weight'], inplace = True)

#Making Weight Dtype integer instead of object
fifaData['Weight'] = fifaData['Weight'].astype(int)

#Renaming the column from Weight to Weight (lbs)
fifaData = fifaData.rename(columns={'Weight': 'Weight (lbs)'})

# %%
fifaData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17918 entries, 0 to 18206
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        17918 non-null  int64
#  1   Name              17918 non-null  object
#  2   Age               17918 non-null  int64
#  3   Nationality       17918 non-null  object
#  4   Overall           17918 non-null  int64
#  5   Potential         17918 non-null  int64
#  6   Wage (Thousands)  17918 non-null  int64
#  7   Height (cm)       17918 non-null  float64
#  8   Weight (lbs)      17918 non-null  int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 1.4+ MB

# %%
f, axes = plt.subplots(figsize=(24, 12))
sb.histplot(data = fifaData['Wage (Thousands)'])
# Out:
# <AxesSubplot:xlabel='Wage (Thousands)', ylabel='Count'>

# %%
q_low = fifaData["Wage (Thousands)"].quantile(0.01)
q_hi  = fifaData["Wage (Thousands)"].quantile(0.99)

fifaDatafiltered = fifaData[(fifaData["Wage (Thousands)"] < q_hi) & (fifaData["Wage (Thousands)"] > q_low)]
fifaDatafiltered = fifaDatafiltered[fifaDatafiltered['Height (cm)'] >= 160]

# %%
fifaDatafiltered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9559 entries, 9 to 18167
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        9559 non-null   int64
#  1   Name              9559 non-null   object
#  2   Age               9559 non-null   int64
#  3   Nationality       9559 non-null   object
#  4   Overall           9559 non-null   int64
#  5   Potential         9559 non-null   int64
#  6   Wage (Thousands)  9559 non-null   int64
#  7   Height (cm)       9559 non-null   float64
#  8   Weight (lbs)      9559 non-null   int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 746.8+ KB

# %%
f, axes = plt.subplots(figsize=(24, 12))
sb.histplot(data = fifaDatafiltered['Wage (Thousands)'])
# Out:
# <AxesSubplot:xlabel='Wage (Thousands)', ylabel='Count'>

# %%
# Set up matplotlib figure with three subplots
f, axes = plt.subplots(2, 3, figsize=(24, 12))

sb.kdeplot(data = fifaDatafiltered['Potential'], ax = axes[0,0])
sb.kdeplot(data = fifaDatafiltered['Overall'], ax = axes[0,1])
sb.kdeplot(data = fifaDatafiltered['Age'], ax = axes[0,2])

sb.kdeplot(data = fifaDatafiltered['Height (cm)'], ax = axes[1,0])
sb.kdeplot(data = fifaDatafiltered['Weight (lbs)'], ax = axes[1,1])
sb.kdeplot(data = fifaDatafiltered['Wage (Thousands)'], ax = axes[1,2])
# Out:
# <AxesSubplot:xlabel='Wage (Thousands)', ylabel='Density'>

# %% [markdown]
# # 1. Comparing Age, Height and Weight with Wage (2 Numerical Datas) (Linear Regression)

# %%
# Set up matplotlib figure with three subplots
f = plt.figure(figsize=(16, 8))
plt.scatter(fifaDatafiltered['Overall'], fifaDatafiltered['Wage (Thousands)'])

# %%
# Set up matplotlib figure with three subplots
f = plt.figure(figsize=(16, 8))
plt.scatter(fifaDatafiltered['Potential'], fifaDatafiltered['Wage (Thousands)'])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

linreg = LinearRegression()
fifaDataWAGE = pd.DataFrame(fifaDatafiltered['Wage (Thousands)'])
fifaDataOVERALL = pd.DataFrame(fifaDatafiltered['Overall'])

# %%
linreg = LinearRegression()         
linreg.fit(fifaDataOVERALL, fifaDataWAGE)        

print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()
# Out:
# Intercept of Regression 	: b =  [-109.5288587]
# Coefficients of Regression 	: a =  [[1.76388997]]

# %%
regline_Overall = fifaDataOVERALL
regline_Wage = linreg.intercept_ + linreg.coef_ * fifaDataOVERALL

f = plt.figure(figsize=(16, 8))
plt.scatter(fifaDataOVERALL, fifaDataWAGE)
plt.plot(regline_Overall, regline_Wage, 'r-', linewidth = 3)
plt.show()

# %%
fifaDataWAGE2 = pd.DataFrame(fifaDatafiltered['Wage (Thousands)'])
fifaDataPOTENTIAL = pd.DataFrame(fifaDatafiltered['Potential'])

# %%
linreg.fit(fifaDataPOTENTIAL, fifaDataWAGE2)        

print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()
# Out:
# Intercept of Regression 	: b =  [-88.09819243]
# Coefficients of Regression 	: a =  [[1.37067939]]

# %%
regline_Potential = fifaDataPOTENTIAL
regline_Wage2 = linreg.intercept_ + linreg.coef_ * fifaDataPOTENTIAL

f = plt.figure(figsize=(16, 8))
plt.scatter(fifaDataPOTENTIAL, fifaDataWAGE2)
plt.plot(regline_Potential, regline_Wage2, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# ### Since the best-fit line does not represent much, a best-fit curve would be better. We would be exploring that in the next section

# %%
fifaDataWAGE3 = pd.DataFrame(fifaDatafiltered['Wage (Thousands)'])
fifaDataAGE = pd.DataFrame(fifaDatafiltered['Age'])

# %%
linreg.fit(fifaDataAGE, fifaDataWAGE3)        

print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()
# Out:
# Intercept of Regression 	: b =  [2.59101651]
# Coefficients of Regression 	: a =  [[0.32695784]]

# %%
regline_Age = fifaDataAGE
regline_Wage3 = linreg.intercept_ + linreg.coef_ * fifaDataAGE

f = plt.figure(figsize=(16, 8))
plt.scatter(fifaDataAGE, fifaDataWAGE3)
plt.plot(regline_Age, regline_Wage3, 'r-', linewidth = 3)
plt.show()

# %%
# Predict Total values corresponding to HP Train
wage_train_pred = linreg.predict(fifaDataAGE)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(fifaDataAGE, fifaDataWAGE3)
plt.scatter(fifaDataAGE, wage_train_pred, color = "r")
plt.show()

# %%
# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(fifaDataAGE, fifaDataWAGE3))

# Mean Squared Error (MSE)
def mean_sq_err(actual, predicted):
    '''Returns the Mean Squared Error of actual and predicted values'''
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(fifaDataWAGE3, wage_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.009975693081865744
# Mean Squared Error (MSE) 	: 205.93051751040701
# Root Mean Squared Error (RMSE) 	: 14.350279353044213

# %%
fifaDataWAGE4 = pd.DataFrame(fifaDatafiltered['Wage (Thousands)'])
fifaDataHEIGHT = pd.DataFrame(fifaDatafiltered['Height (cm)'])

# %%
linreg.fit(fifaDataHEIGHT, fifaDataWAGE4)        

print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()
# Out:
# Intercept of Regression 	: b =  [-7.2297081]
# Coefficients of Regression 	: a =  [[0.09953887]]

# %%
regline_Height = fifaDataHEIGHT
regline_Wage4 = linreg.intercept_ + linreg.coef_ * fifaDataHEIGHT

f = plt.figure(figsize=(16, 8))
plt.scatter(fifaDataHEIGHT, fifaDataWAGE4)
plt.plot(regline_Height, regline_Wage4, 'r-', linewidth = 3)
plt.show()

# %%
# Predict Total values corresponding to HP Train
wage2_train_pred = linreg.predict(fifaDataHEIGHT)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(fifaDataHEIGHT, fifaDataWAGE4)
plt.scatter(fifaDataHEIGHT, wage2_train_pred, color = "r")
plt.show()

# %%
# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(fifaDataHEIGHT, fifaDataWAGE4))

# Mean Squared Error (MSE)
def mean_sq_err(actual, predicted):
    '''Returns the Mean Squared Error of actual and predicted values'''
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(fifaDataWAGE4, wage2_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.002127489458595866
# Mean Squared Error (MSE) 	: 207.56298716026652
# Root Mean Squared Error (RMSE) 	: 14.407046441247648

# %%
fifaDataWAGE5 = pd.DataFrame(fifaDatafiltered['Wage (Thousands)'])
fifaDataWEIGHT = pd.DataFrame(fifaDatafiltered['Weight (lbs)'])

# %%
linreg.fit(fifaDataWEIGHT, fifaDataWAGE5)        

print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()
# Out:
# Intercept of Regression 	: b =  [-1.42505292]
# Coefficients of Regression 	: a =  [[0.07445627]]

# %%
regline_Weight = fifaDataWEIGHT
regline_Wage5 = linreg.intercept_ + linreg.coef_ * fifaDataWEIGHT

f = plt.figure(figsize=(16, 8))
plt.scatter(fifaDataWEIGHT, fifaDataWAGE5)
plt.plot(regline_Weight, regline_Wage5, 'r-', linewidth = 3)
plt.show()

# %%
# Predict Total values corresponding to HP Train
wage3_train_pred = linreg.predict(fifaDataWEIGHT)

# Plot the Linear Regression line
f = plt.figure(figsize=(16, 8))
plt.scatter(fifaDataWEIGHT, fifaDataWAGE5)
plt.scatter(fifaDataWEIGHT, wage3_train_pred, color = "r")
plt.show()

# %%
# Explained Variance (R^2)
print("Explained Variance (R^2) \t:", linreg.score(fifaDataWEIGHT, fifaDataWAGE5))

# Mean Squared Error (MSE)
def mean_sq_err(actual, predicted):
    '''Returns the Mean Squared Error of actual and predicted values'''
    return np.mean(np.square(np.array(actual) - np.array(predicted)))

mse = mean_sq_err(fifaDataWAGE5, wage3_train_pred)
print("Mean Squared Error (MSE) \t:", mse)
print("Root Mean Squared Error (RMSE) \t:", np.sqrt(mse))
# Out:
# Explained Variance (R^2) 	: 0.0075929542968838915
# Mean Squared Error (MSE) 	: 206.42614032254878
# Root Mean Squared Error (RMSE) 	: 14.36753772650515

# %% [markdown]
# ### Out of the three, age has the highest R^2 value and the lowest RMSE. This means that out of the three age is the one that can most likely be used to determine
#
# ### However, the R^2 values of all three when compared to wage are extremely close to 0. This means that all the values are identical, which means that a regression line would not work in this case. Thus, these three factors cannot be used to determine the salary of a footballer.

# %% [markdown]
# # 2. Comparing Overall and Potential with Wage (2 Numerical Datas) (Exponential Regression)

# %%
WageVsOverall = fifaDatafiltered.copy()
WageVsOverall.drop(['Name', 'Age', 'Nationality', 'Potential', 'Weight (lbs)', 
                    'Height (cm)', 'Unnamed: 0'], axis=1, inplace = True)

WageVsOverall.info()

f = plt.figure(figsize=(16, 8))
sb.regplot(data = WageVsOverall, x = 'Overall', y = 'Wage (Thousands)', lowess=True, 
          scatter_kws={'alpha':1, 's':5,'color':'green'}, line_kws={'color':'red'})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9559 entries, 9 to 18167
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Overall           9559 non-null   int64
#  1   Wage (Thousands)  9559 non-null   int64
# dtypes: int64(2)
# memory usage: 224.0 KB
# <AxesSubplot:xlabel='Overall', ylabel='Wage (Thousands)'>

# %%
WageVsPotential = fifaDatafiltered.copy()
WageVsPotential.drop(['Name', 'Age', 'Nationality', 'Overall', 'Weight (lbs)', 
                    'Height (cm)', 'Unnamed: 0'], axis=1, inplace = True)

WageVsPotential.info()

f = plt.figure(figsize=(16, 8))
sb.regplot(data = WageVsPotential, x = 'Potential', y = 'Wage (Thousands)', lowess=True, 
          scatter_kws={'alpha':1, 's':5,'color':'green'}, line_kws={'color':'red'})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9559 entries, 9 to 18167
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Potential         9559 non-null   int64
#  1   Wage (Thousands)  9559 non-null   int64
# dtypes: int64(2)
# memory usage: 224.0 KB
# <AxesSubplot:xlabel='Potential', ylabel='Wage (Thousands)'>

# %% [markdown]
# ### Since a best-fit curve can now be used to , we will be using Exponential Regression to calculate the estimate of a footballer's salary using Potential and Overall. We need to find the equation of the line to determine it.

# %% [markdown]
# # WE NEED TO FIND EQUATION OF THE EXPONENTIAL CURVE AND FIND MEAN SQUARED ERROR SO THAT WE CAN USE OVERALL AND POTENTIAL TO PREDICT SALARY

# %% [markdown]
# # 3. Comparing Nationality with Wage (Numerical vs Categorical Data) (Classification Tree)

# %%
sb.catplot(y = "Nationality", data = fifaDatafiltered, kind = "count", height = 8)

# %%
# Secondary Types in the Dataset
print("Number of Nationalities :", len(fifaDatafiltered["Nationality"].dropna().unique()))

# Players of each Nationality
print(fifaDatafiltered["Nationality"].dropna().value_counts())
# Out:
# Number of Nationalities : 147
# England          944
# Spain            669
# Germany          618
# Argentina        605
# Brazil           541
#                 ...
# Guam               1
# Fiji               1
# New Caledonia      1
# Mauritius          1
# South Sudan        1
# Name: Nationality, Length: 147, dtype: int64

# %% [markdown]
# ### We will then remove the countries that have counts lesser than 100

# %%
vc = fifaDatafiltered["Nationality"].dropna().value_counts()
print (vc[vc > 150])
# Out:
# England          944
# Spain            669
# Germany          618
# Argentina        605
# Brazil           541
# France           515
# Italy            369
# Netherlands      261
# Mexico           251
# Saudi Arabia     241
# China PR         222
# Portugal         211
# Denmark          199
# Japan            186
# United States    181
# Turkey           179
# Austria          177
# Belgium          161
# Colombia         156
# Name: Nationality, dtype: int64

# %% [markdown]
# ### Now that we have found the unique countries that have counts more than 100, we can use them to plot box-plots to see if there are any interesting things to explore.

# %%
#Removing the countries that are not in this
fifaDatafiltered2 = fifaDatafiltered.loc[fifaData["Nationality"] == ('England', 'Spain', 'Germany', 'Argentina',
                                                                     'Brazil', 'France', 'Italy','Netherlands', 
                                                                     'Mexico', 'Saudi Arabia', 'China PR', 'Portugal',
                                                                     'Denmark', 'Japan', 'United States', 'Turkey',
                                                                     'Austria', 'Belgium', 'Colombia')]

# %%
fifaDatafiltered2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        0 non-null      int64
#  1   Name              0 non-null      object
#  2   Age               0 non-null      int64
#  3   Nationality       0 non-null      object
#  4   Overall           0 non-null      int64
#  5   Potential         0 non-null      int64
#  6   Wage (Thousands)  0 non-null      int64
#  7   Height (cm)       0 non-null      float64
#  8   Weight (lbs)      0 non-null      int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 0.0+ bytes
